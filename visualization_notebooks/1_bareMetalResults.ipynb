# %% [markdown]
# # Memory Subsystem Benchmarking - Sysbench: Linux Host
# ---
# ## 1. Parse Sysbench Results

# %%
import re
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.DataFrame(columns=['Exec Env', '#vCPUs', 'Access Method', 'Number of Threads',
                           'Block Size (KiB)', 'Total Size (MiB)', 'Operation', 'Scope',
                           'Total Ops', 'Ops per sec',
                           'Data Transfered (MiB)', 'Throughput (MiB/sec)',
                           'Total Time', 'Total #events',
                           'Min Latency (ms)',
                           'Avg Latency (ms)',
                           'Max Latency (ms)',
                           '95th Percentile Latency (ms)',
                           'Total Execution Time across Threads (s)',
                           'Avg Number of Events per Thread',
                           'Avg Execution Time per Thread (s)'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Exec Env, #vCPUs, Access Method, Number of Threads, Block Size (KiB), Total Size (MiB), Operation, Scope, Total Ops, Ops per sec, Data Transfered (MiB), Throughput (MiB/sec), Total Time, Total #events, Min Latency (ms), Avg Latency (ms), Max Latency (ms), 95th Percentile Latency (ms), Total Execution Time across Threads (s), Avg Number of Events per Thread, Avg Execution Time per Thread (s)]
# Index: []
#
# [0 rows x 21 columns]

# %%
for outputFile in os.listdir('../test_outputs/bareMetalOutputs'):
    linenum = 0
    filepath = os.path.join('../test_outputs/bareMetalOutputs', outputFile)
    if outputFile == '.gitkeep':
        continue
    with open(filepath, 'r') as f:
        testResult = ['Linux Host', 96, outputFile.split('_')[2]]
        for line in f:
            if ':' in line or 'MiB' in line:
                result = line.rsplit(':', 1)
                if len(result) > 1: result = result[1].strip()
                else: result = result[0]
                if 'per second' in result:
                    vals = result.split('(')
                    testResult.append(float(vals[0].strip()))
                    testResult.append(float(vals[1][:-11].strip()))
                elif 'transferred' in result:
                    testResult += map(float, re.findall(r"(?<![a-zA-Z:])[-+]?\d*\.?\d+", result))
                elif 'MiB' in result or 'KiB' in result:
                    testResult.append(float(result[:-3]))
                elif '/' in result:
                    testResult.append(float(result.split('/')[0]))
                elif 's' in result:
                    testResult.append(float(result[:-1]))
                elif result != '':
                    try:
                        testResult.append(float(result))
                    except: testResult.append(result) 
    df.loc[len(df)] = testResult

# %%
df.head()
# Out:
#      Exec Env  #vCPUs Access Method  Number of Threads  Block Size (KiB)  \
# 0  Linux Host      96           rnd               30.0            4096.0
# 1  Linux Host      96           rnd               20.0            4096.0
# 2  Linux Host      96           seq               26.0            4096.0
# 3  Linux Host      96           seq               37.0            4096.0
# 4  Linux Host      96           seq               14.0            4096.0
#
#    Total Size (MiB) Operation   Scope  Total Ops  Ops per sec  ...  \
# 0         1024000.0     write  global    17264.0       574.89  ...
# 1         1024000.0     write  global    13376.0       445.46  ...
# 2         1024000.0     write  global   146078.0      4868.41  ...
# 3         1024000.0     write   local   255966.0     32259.00  ...
# 4         1024000.0      read   local   255990.0     83751.57  ...
#
#    Throughput (MiB/sec)  Total Time  Total #events  Min Latency (ms)  \
# 0               2299.55     30.0285        17264.0             20.87
# 1               1781.84     30.0253        13376.0             19.34
# 2              19473.64     30.0038       146078.0              0.53
# 3             129035.99      7.9310       255966.0              0.21
# 4             335006.26      3.0525       255990.0              0.09
#
#    Avg Latency (ms)  Max Latency (ms)  95th Percentile Latency (ms)  \
# 0             52.15            425.31                        114.72
# 1             44.87            308.53                         68.05
# 2              5.12             98.80                         15.83
# 3              0.80            149.31                          2.43
# 4              0.15             37.86                          0.11
#
#    Total Execution Time across Threads (s)  Avg Number of Events per Thread  \
# 0                                900309.12                         575.4667
# 1                                600235.32                         668.8000
# 2                                748539.98                        5618.3846
# 3                                205906.00                        6918.0000
# 4                                 38811.02                       18285.0000
#
#    Avg Execution Time per Thread (s)
# 0                            30.0103
# 1                            30.0118
# 2                            28.7900
# 3                             5.5650
# 4                             2.7722
#
# [5 rows x 21 columns]

# %%
df = df.astype({'Number of Threads': int})\
       .sort_values(by=['Number of Threads', 'Operation', 'Access Method', 'Scope']).reset_index(drop=True)

df['Total Execution Time across Threads (s)'] = df['Total Execution Time across Threads (s)'] / 1000

# %%
df.head(20)
# Out:
#       Exec Env  #vCPUs Access Method  Number of Threads  Block Size (KiB)  \
# 0   Linux Host      96           rnd                  1            4096.0
# 1   Linux Host      96           rnd                  1            4096.0
# 2   Linux Host      96           seq                  1            4096.0
# 3   Linux Host      96           seq                  1            4096.0
# 4   Linux Host      96           rnd                  1            4096.0
# 5   Linux Host      96           rnd                  1            4096.0
# 6   Linux Host      96           seq                  1            4096.0
# 7   Linux Host      96           seq                  1            4096.0
# 8   Linux Host      96           rnd                  2            4096.0
# 9   Linux Host      96           rnd                  2            4096.0
# 10  Linux Host      96           seq                  2            4096.0
# 11  Linux Host      96           seq                  2            4096.0
# 12  Linux Host      96           rnd                  2            4096.0
# 13  Linux Host      96           rnd                  2            4096.0
# 14  Linux Host      96           seq                  2            4096.0
# 15  Linux Host      96           seq                  2            4096.0
# 16  Linux Host      96           rnd                  3            4096.0
# 17  Linux Host      96           rnd                  3            4096.0
# 18  Linux Host      96           seq                  3            4096.0
# 19  Linux Host      96           seq                  3            4096.0
#
#     Total Size (MiB) Operation   Scope  Total Ops  Ops per sec  ...  \
# 0          1024000.0      read  global    12323.0       410.73  ...
# 1          1024000.0      read   local    12158.0       405.21  ...
# 2          1024000.0      read  global   256000.0     10748.42  ...
# 3          1024000.0      read   local   256000.0     10737.39  ...
# 4          1024000.0     write  global     5819.0       193.94  ...
# 5          1024000.0     write   local     5819.0       193.93  ...
# 6          1024000.0     write  global   140837.0      4693.95  ...
# 7          1024000.0     write   local   140850.0      4694.38  ...
# 8          1024000.0      read  global    24773.0       825.66  ...
# 9          1024000.0      read   local    24523.0       817.28  ...
# 10         1024000.0      read  global   256000.0     21428.09  ...
# 11         1024000.0      read   local   256000.0     20813.18  ...
# 12         1024000.0     write  global     5401.0       180.00  ...
# 13         1024000.0     write   local    11616.0       387.14  ...
# 14         1024000.0     write  global    69948.0      2331.28  ...
# 15         1024000.0     write   local   256000.0      9249.10  ...
# 16         1024000.0      read  global    37355.0      1244.91  ...
# 17         1024000.0      read   local    36172.0      1205.33  ...
# 18         1024000.0      read  global   255999.0     31355.25  ...
# 19         1024000.0      read   local   255999.0     30426.98  ...
#
#     Throughput (MiB/sec)  Total Time  Total #events  Min Latency (ms)  \
# 0                1642.93     30.0010        12323.0              2.41
# 1                1620.85     30.0003        12158.0              2.43
# 2               42993.67     23.8139       256000.0              0.09
# 3               42949.56     23.8383       256000.0              0.09
# 4                 775.77     30.0004         5819.0              2.20
# 5                 775.73     30.0015         5819.0              2.19
# 6               18775.81     30.0003       140837.0              0.21
# 7               18777.53     30.0004       140850.0              0.21
# 8                3302.64     30.0020        24773.0              2.35
# 9                3269.12     30.0018        24523.0              2.35
# 10              85712.36     11.9433       256000.0              0.09
# 11              83252.73     12.2963       256000.0              0.09
# 12                720.02     30.0012         5401.0              3.15
# 13               1548.56     30.0009        11616.0              2.20
# 14               9325.10     30.0009        69948.0              0.21
# 15              36996.39     27.6747       256000.0              0.21
# 16               4979.65     30.0024        37355.0              2.35
# 17               4821.34     30.0061        36172.0              2.38
# 18             125420.98      8.1612       255999.0              0.09
# 19             121707.93      8.4097       255999.0              0.09
#
#     Avg Latency (ms)  Max Latency (ms)  95th Percentile Latency (ms)  \
# 0               2.43              7.92                          2.48
# 1               2.47              7.41                          2.52
# 2               0.09              0.68                          0.09
# 3               0.09              0.55                          0.09
# 4               5.15             10.95                          5.18
# 5               5.15              9.87                          5.18
# 6               0.21              2.14                          0.22
# 7               0.21              0.77                          0.22
# 8               2.42             11.52                          2.48
# 9               2.45             14.17                          2.52
# 10              0.09              2.49                          0.09
# 11              0.09             13.56                          0.10
# 12             11.11             21.94                         17.32
# 13              5.16             22.62                          5.28
# 14              0.86              5.54                          1.37
# 15              0.21             12.19                          0.22
# 16              2.41             13.25                          2.61
# 17              2.49             18.78                          2.71
# 18              0.09              3.05                          0.10
# 19              0.10             11.51                          0.11
#
#     Total Execution Time across Threads (s)  Avg Number of Events per Thread  \
# 0                                  29.99633                       12323.0000
# 1                                  29.99468                       12158.0000
# 2                                  23.77626                      256000.0000
# 3                                  23.80058                      256000.0000
# 4                                  29.99567                        5819.0000
# 5                                  29.99606                        5819.0000
# 6                                  29.97677                      140837.0000
# 7                                  29.97659                      140850.0000
# 8                                  59.98900                       12386.5000
# 9                                  59.98619                       12261.5000
# 10                                 23.73144                      128000.0000
# 11                                 24.14537                      128000.0000
# 12                                 59.99414                        2700.5000
# 13                                 59.99073                        5808.0000
# 14                                 59.97365                       34974.0000
# 15                                 54.95437                      128000.0000
# 16                                 89.98596                       12451.6667
# 17                                 89.98945                       12057.3333
# 18                                 24.17998                       85333.0000
# 19                                 24.78469                       85333.0000
#
#     Avg Execution Time per Thread (s)
# 0                             29.9963
# 1                             29.9947
# 2                             23.7763
# 3                             23.8006
# 4                             29.9957
# 5                             29.9961
# 6                             29.9768
# 7                             29.9766
# 8                             29.9945
# 9                             29.9931
# 10                            11.8657
# 11                            12.0727
# 12                            29.9971
# 13                            29.9954
# 14                            29.9868
# 15                            27.4772
# 16                            29.9953
# 17                            29.9965
# 18                             8.0600
# 19                             8.2616
#
# [20 rows x 21 columns]

# %%
df.to_csv('../result_CSVs/bareMetalResults.csv')

# %% [markdown]
# ## 2. Visualization
# - Variables: operation (read, write), scope (global, local), access method (rnd, seq)
# - To visualize: avg latency, number of events per thread, amount of data transferred, ops per sec, throughput
